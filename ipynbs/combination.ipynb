# %%
import pandas as pd
from tidyframe.tools import combination

# %%
df_a = pd.DataFrame({'a1':list('ABC'), 'a2':list('CDE')})
df_b = pd.DataFrame({'b1':list('01234'), 'b2':list('56789')})
df_c = pd.DataFrame({'c1':list('pq'), 'c2':list('rs')})
df_d = pd.DataFrame({'d1':list('abcd'), 'd2':list('efgh')})

# %%
df_d.index.name = 'index'

# %%
df_d
# Out:
#       d1 d2
# index
# 0      a  e
# 1      b  f
# 2      c  g
# 3      d  h

# %%
combination([df_a, df_b, df_c])
# Out:
#     index_0 a1 a2  index_1 b1 b2  index_2 c1 c2
# 0         0  A  C        0  0  5        0  p  r
# 1         0  A  C        0  0  5        1  q  s
# 2         0  A  C        1  1  6        0  p  r
# 3         0  A  C        1  1  6        1  q  s
# 4         0  A  C        2  2  7        0  p  r
# 5         0  A  C        2  2  7        1  q  s
# 6         0  A  C        3  3  8        0  p  r
# 7         0  A  C        3  3  8        1  q  s
# 8         0  A  C        4  4  9        0  p  r
# 9         0  A  C        4  4  9        1  q  s
# 10        1  B  D        0  0  5        0  p  r
# 11        1  B  D        0  0  5        1  q  s
# 12        1  B  D        1  1  6        0  p  r
# 13        1  B  D        1  1  6        1  q  s
# 14        1  B  D        2  2  7        0  p  r
# 15        1  B  D        2  2  7        1  q  s
# 16        1  B  D        3  3  8        0  p  r
# 17        1  B  D        3  3  8        1  q  s
# 18        1  B  D        4  4  9        0  p  r
# 19        1  B  D        4  4  9        1  q  s
# 20        2  C  E        0  0  5        0  p  r
# 21        2  C  E        0  0  5        1  q  s
# 22        2  C  E        1  1  6        0  p  r
# 23        2  C  E        1  1  6        1  q  s
# 24        2  C  E        2  2  7        0  p  r
# 25        2  C  E        2  2  7        1  q  s
# 26        2  C  E        3  3  8        0  p  r
# 27        2  C  E        3  3  8        1  q  s
# 28        2  C  E        4  4  9        0  p  r
# 29        2  C  E        4  4  9        1  q  s

# %%
combination([df_a, df_b, df_d])
# Out:
#     index_0 a1 a2  index_1 b1 b2  index_2 d1 d2
# 0         0  A  C        0  0  5        0  a  e
# 1         0  A  C        0  0  5        1  b  f
# 2         0  A  C        0  0  5        2  c  g
# 3         0  A  C        0  0  5        3  d  h
# 4         0  A  C        1  1  6        0  a  e
# 5         0  A  C        1  1  6        1  b  f
# 6         0  A  C        1  1  6        2  c  g
# 7         0  A  C        1  1  6        3  d  h
# 8         0  A  C        2  2  7        0  a  e
# 9         0  A  C        2  2  7        1  b  f
# 10        0  A  C        2  2  7        2  c  g
# 11        0  A  C        2  2  7        3  d  h
# 12        0  A  C        3  3  8        0  a  e
# 13        0  A  C        3  3  8        1  b  f
# 14        0  A  C        3  3  8        2  c  g
# 15        0  A  C        3  3  8        3  d  h
# 16        0  A  C        4  4  9        0  a  e
# 17        0  A  C        4  4  9        1  b  f
# 18        0  A  C        4  4  9        2  c  g
# 19        0  A  C        4  4  9        3  d  h
# 20        1  B  D        0  0  5        0  a  e
# 21        1  B  D        0  0  5        1  b  f
# 22        1  B  D        0  0  5        2  c  g
# 23        1  B  D        0  0  5        3  d  h
# 24        1  B  D        1  1  6        0  a  e
# 25        1  B  D        1  1  6        1  b  f
# 26        1  B  D        1  1  6        2  c  g
# 27        1  B  D        1  1  6        3  d  h
# 28        1  B  D        2  2  7        0  a  e
# 29        1  B  D        2  2  7        1  b  f
# 30        1  B  D        2  2  7        2  c  g
# 31        1  B  D        2  2  7        3  d  h
# 32        1  B  D        3  3  8        0  a  e
# 33        1  B  D        3  3  8        1  b  f
# 34        1  B  D        3  3  8        2  c  g
# 35        1  B  D        3  3  8        3  d  h
# 36        1  B  D        4  4  9        0  a  e
# 37        1  B  D        4  4  9        1  b  f
# 38        1  B  D        4  4  9        2  c  g
# 39        1  B  D        4  4  9        3  d  h
# 40        2  C  E        0  0  5        0  a  e
# 41        2  C  E        0  0  5        1  b  f
# 42        2  C  E        0  0  5        2  c  g
# 43        2  C  E        0  0  5        3  d  h
# 44        2  C  E        1  1  6        0  a  e
# 45        2  C  E        1  1  6        1  b  f
# 46        2  C  E        1  1  6        2  c  g
# 47        2  C  E        1  1  6        3  d  h
# 48        2  C  E        2  2  7        0  a  e
# 49        2  C  E        2  2  7        1  b  f
# 50        2  C  E        2  2  7        2  c  g
# 51        2  C  E        2  2  7        3  d  h
# 52        2  C  E        3  3  8        0  a  e
# 53        2  C  E        3  3  8        1  b  f
# 54        2  C  E        3  3  8        2  c  g
# 55        2  C  E        3  3  8        3  d  h
# 56        2  C  E        4  4  9        0  a  e
# 57        2  C  E        4  4  9        1  b  f
# 58        2  C  E        4  4  9        2  c  g
# 59        2  C  E        4  4  9        3  d  h
